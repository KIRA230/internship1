# %%
# !pip install selenium

# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common .by import By
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver=webdriver.Chrome(r'C:\Users\Pankaj Hardas\Desktop\EXtract\chromedriver.exe')

# %%
driver.maximize_window()

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %% [markdown]
# #Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.

# %%
url='https://www.naukri.com/'
driver.get(url)

# %%
job=driver.find_element(By.CLASS_NAME,'suggestor-input ')
job.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH, '/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
location.send_keys('Banglore')

# %%
search_btn=driver.find_element(By.XPATH, '/html/body/div[1]/div[6]/div/div/div[6]')
search_btn.click()

# %%
job_titles=[]
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags:
    job_titles.append(i.text)
job_titles[0:10]
# Out:
# ['Lead Data Analyst',
#  'Sr. Data Analyst (SAS Data Management)',
#  'Data Analyst - Consumer Analytics',
#  'Assistant Manager - Data Analyst',
#  'Manager - Data Analyst - KPO',
#  'Manager - Data Analyst - KPO',
#  'Data Analyst - Python',
#  'Manager - Data Analyst - KPO',
#  'Data Analyst',
#  'Data Analyst/ Sr Data Analyst (For an Agro-tech company)']

# %%
company_name=[]
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags:
    company_name.append(i.text)
company_name[0:10]
# Out:
# ['Mobile Premier League (MPL)',
#  'NMS Consultant',
#  'Eli Lilly And Company',
#  'Huquo Consulting Pvt. Ltd',
#  'Huquo Consulting Pvt. Ltd',
#  'Huquo Consulting Pvt. Ltd',
#  'Huquo Consulting Pvt. Ltd',
#  'Huquo Consulting Pvt. Ltd',
#  'Phonepe',
#  'Uberlife Consulting Private Limited']

# %%
Experiance_req=[]
Experiance_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in Experiance_tags:
    Experiance_req.append(i.text[0:10])
Experiance_req[0:10]
# Out:
# ['4-7 Yrs',
#  '5-10 Yrs',
#  '2-4 Yrs',
#  '3-6 Yrs',
#  '5-9 Yrs',
#  '3-8 Yrs',
#  '4-9 Yrs',
#  '2-7 Yrs',
#  '1-3 Yrs',
#  '5-10 Yrs']

# %%
location=[]
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags:
    location.append(i.text)
len(location)    
location[0:10]
# Out:
# ['Bangalore/Bengaluru',
#  'New Delhi, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Gurgaon/Gurugram, Bangalore/Bengaluru',
#  'Gurgaon/Gurugram, Bangalore/Bengaluru',
#  'Gurgaon/Gurugram, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru']

# %%
jobs=pd.DataFrame()
jobs['Job Name']=job_titles[0:10]
jobs['Company']=company_name[0:10]
jobs['Experiance']=Experiance_req[0:10]
jobs['Location']=location[0:10]
jobs
# Out:
#                                             Job Name  \
# 0                                  Lead Data Analyst
# 1             Sr. Data Analyst (SAS Data Management)
# 2                  Data Analyst - Consumer Analytics
# 3                   Assistant Manager - Data Analyst
# 4                       Manager - Data Analyst - KPO
# 5                       Manager - Data Analyst - KPO
# 6                              Data Analyst - Python
# 7                       Manager - Data Analyst - KPO
# 8                                       Data Analyst
# 9  Data Analyst/ Sr Data Analyst (For an Agro-tec...
#
#                                Company Experiance  \
# 0          Mobile Premier League (MPL)    4-7 Yrs
# 1                       NMS Consultant   5-10 Yrs
# 2                Eli Lilly And Company    2-4 Yrs
# 3            Huquo Consulting Pvt. Ltd    3-6 Yrs
# 4            Huquo Consulting Pvt. Ltd    5-9 Yrs
# 5            Huquo Consulting Pvt. Ltd    3-8 Yrs
# ...

# %% [markdown]
# #Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.

# %%
url='https://www.naukri.com/'
driver.get(url)

# %%
job=driver.find_element(By.CLASS_NAME,'suggestor-input ')
job.send_keys("Data Scientist")

# %%
location=driver.find_element(By.XPATH, '/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
location.send_keys('Banglore')

# %%
search_btn=driver.find_element(By.XPATH, '/html/body/div[1]/div[6]/div/div/div[6]')
search_btn.click()

# %%
job_titles=[]
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags:
    job_titles.append(i.text)
job_titles[0:10]
# Out:
# ['Analystics & Modeling Specialist',
#  'Senior Data Scientist',
#  'Data Scientist - Looking For Immediate Joiners',
#  'Assistant Manager - Data Science',
#  'Data Scientist',
#  'Data Scientist - 2',
#  'Data Scientist',
#  'Assistant Vice President - Data Scientist - KPO',
#  'Data Scientist',
#  'Senior Data Scientist']

# %%
company_name=[]
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags:
    company_name.append(i.text)
company_name[0:10]
# Out:
# ['Accenture',
#  'Wipro',
#  'Wipro',
#  'Citiustech',
#  'Altair',
#  '24 7 ai',
#  'HCLTech',
#  'Huquo Consulting Pvt. Ltd',
#  'Infinics Global Solutions Pvt Ltd',
#  'Boston Consulting Group']

# %%
Experiance_req=[]
Experiance_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in Experiance_tags:
    Experiance_req.append(i.text[0:10])
Experiance_req[0:10]
# Out:
# ['6-8 Yrs',
#  '6-11 Yrs',
#  '5-10 Yrs',
#  '5-9 Yrs',
#  '2-7 Yrs',
#  '1-3 Yrs',
#  '4-9 Yrs',
#  '6-11 Yrs',
#  '7-12 Yrs',
#  '5-10 Yrs']

# %%
location=[]
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags:
    location.append(i.text)
len(location)    
location[0:10]
# Out:
# ['Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#  'Hybrid - Pune, Chennai, Bangalore/Bengaluru',
#  'Hybrid - Hyderabad/Secunderabad, Bangalore/Bengaluru',
#  'Hybrid - Mumbai, Pune, Bangalore/Bengaluru',
#  'Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Noida, Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru',
#  'Mumbai, Hyderabad/Secunderabad, Pune, Gurgaon/Gurugram, Chennai, Bangalore/Bengaluru, Delhi / NCR',
#  'Kolkata, Hyderabad/Secunderabad, Pune, Ahmedabad, Chennai, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)',
#  'Mumbai, New Delhi, Chennai, Bangalore/Bengaluru']

# %%
jobs=pd.DataFrame()
jobs['Job Name']=job_titles[0:10]
jobs['Company']=company_name[0:10]
jobs['Experiance']=Experiance_req[0:10]
jobs['Location']=location[0:10]
jobs
# Out:
#                                           Job Name  \
# 0                 Analystics & Modeling Specialist
# 1                            Senior Data Scientist
# 2   Data Scientist - Looking For Immediate Joiners
# 3                 Assistant Manager - Data Science
# 4                                   Data Scientist
# 5                               Data Scientist - 2
# 6                                   Data Scientist
# 7  Assistant Vice President - Data Scientist - KPO
# 8                                   Data Scientist
# 9                            Senior Data Scientist
#
#                              Company Experiance  \
# 0                          Accenture    6-8 Yrs
# 1                              Wipro   6-11 Yrs
# 2                              Wipro   5-10 Yrs
# 3                         Citiustech    5-9 Yrs
# 4                             Altair    2-7 Yrs
# 5                            24 7 ai    1-3 Yrs
# 6                            HCLTech    4-9 Yrs
# ...

# %% [markdown]
# #Q3: In this question you have to scrape data using the filters available on the webpage as shown below

# %%
url='https://www.naukri.com/'
driver.get(url)

# %%
job=driver.find_element(By.CLASS_NAME,'suggestor-input ')
job.send_keys("Data Scientist")

# %%
location=driver.find_element(By.XPATH, '/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
location.send_keys('Delhi/ncr')

# %%
search_btn=driver.find_element(By.XPATH, '/html/body/div[1]/div[6]/div/div/div[6]')
search_btn.click()

# %%
job_titles=[]
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags:
    job_titles.append(i.text)
job_titles[0:10]
# Out:
# ['Data Scientist',
#  'Assistant Vice President - Data Scientist - KPO',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Opportunity For Data Scientist - Female Candidates ONLY',
#  'Data Scientist']

# %%
company_name=[]
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags:
    company_name.append(i.text)
company_name[0:10]
# Out:
# ['HCLTech',
#  'Huquo Consulting Pvt. Ltd',
#  'Infinics Global Solutions Pvt Ltd',
#  'Boston Consulting Group',
#  'TRH Consultancy Services',
#  'TRH Consultancy Services',
#  'TRH Consultancy Services',
#  'TRH Consultancy Services',
#  'PayU Finance',
#  'Trh Consultancy Services']

# %%
Experiance_req=[]
Experiance_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in Experiance_tags:
    Experiance_req.append(i.text[0:10])
Experiance_req[0:10]
# Out:
# ['4-9 Yrs',
#  '6-11 Yrs',
#  '7-12 Yrs',
#  '5-10 Yrs',
#  '5-10 Yrs',
#  '8-13 Yrs',
#  '5-10 Yrs',
#  '5-10 Yrs',
#  '3-7 Yrs',
#  '5-10 Yrs']

# %%
location=[]
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags:
    location.append(i.text)
len(location)    
location[0:10]
# Out:
# ['Noida, Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru',
#  'Delhi / NCR, Mumbai, Hyderabad/Secunderabad, Pune, Gurgaon/Gurugram, Chennai, Bangalore/Bengaluru',
#  'Delhi / NCR, Kolkata, Hyderabad/Secunderabad, Pune, Ahmedabad, Chennai, Bangalore/Bengaluru, Mumbai (All Areas)',
#  'Mumbai, New Delhi, Chennai, Bangalore/Bengaluru',
#  'Kolkata, Mumbai, Nagpur, Hyderabad/Secunderabad, Pune, Chennai, Coimbatore, Bangalore/Bengaluru, Delhi',
#  'Delhi / NCR, Noida, Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Coimbatore, Bangalore/Bengaluru',
#  'Noida, Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Coimbatore, Bangalore/Bengaluru, Delhi',
#  'Delhi / NCR, Noida, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#  'Hybrid - Gurgaon/Gurugram, Bangalore/Bengaluru, Mumbai (All Areas)',
#  'Noida, Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Coimbatore, Bangalore/Bengaluru']

# %%
jobs=pd.DataFrame()
jobs['Job Name']=job_titles[0:10]
jobs['Company']=company_name[0:10]
jobs['Experiance']=Experiance_req[0:10]
jobs['Location']=location[0:10]
jobs
# Out:
#                                             Job Name  \
# 0                                     Data Scientist
# 1    Assistant Vice President - Data Scientist - KPO
# 2                                     Data Scientist
# 3                              Senior Data Scientist
# 4                                     Data Scientist
# 5                                     Data Scientist
# 6                                     Data Scientist
# 7                                     Data Scientist
# 8  Opportunity For Data Scientist - Female Candid...
# 9                                     Data Scientist
#
#                              Company Experiance  \
# 0                            HCLTech    4-9 Yrs
# 1          Huquo Consulting Pvt. Ltd   6-11 Yrs
# 2  Infinics Global Solutions Pvt Ltd   7-12 Yrs
# 3            Boston Consulting Group   5-10 Yrs
# 4           TRH Consultancy Services   5-10 Yrs
# 5           TRH Consultancy Services   8-13 Yrs
# ...

# %% [markdown]
# #Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:

# %%
url='https://www.flipkart.com/'
driver.get(url)

# %%
search=driver.find_element(By.CLASS_NAME,'_3704LK')
search.send_keys("Sunglaases")

# %%
Brand=[]
start=0
end=4
for page in range(start,end):
    Brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in Brand_tags:
        Brand.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')    
                                     
Brand[0:100]
# Out:
# ['Fastrack',
#  'PIRASO',
#  'New Specs',
#  'Silver Kartz',
#  'SUNBEE',
#  'VINCENT CHASE',
#  'Fastrack',
#  'Singco India',
#  'Fastrack',
#  'PIRASO',
#  'ROYAL SON',
#  'ROZZETTA CRAFT',
#  'CRYSTAL CART',
#  'GANSTA',
#  'Elligator',
#  'PIRASO',
#  'ROYAL SON',
#  'ROZZETTA CRAFT',
#  'Sewell',
#  'PIRASO',
#  'Silver Kartz',
#  'ROYAL SON',
#  'ROZZETTA CRAFT',
#  'DEIXELS',
#  'GANSTA',
#  'Fastrack',
#  'ROZZETTA CRAFT',
#  'ROYAL SON',
#  'Elligator',
#  'VINCENT CHASE',
#  'ROYAL SON',
#  'ROYAL SON',
#  'Fastrack',
#  'PIRASO',
#  'Fastrack',
#  'Urbanic',
#  'ROYAL SON',
#  'PROVOGUE',
#  'Fastrack',
#  'kingsunglasses',
#  'Fastrack',
#  'PIRASO',
#  'New Specs',
#  'Silver Kartz',
#  'SUNBEE',
#  'VINCENT CHASE',
#  'Fastrack',
#  'Singco India',
#  'Fastrack',
#  'PIRASO',
#  'ROYAL SON',
#  'ROZZETTA CRAFT',
#  'CRYSTAL CART',
#  'GANSTA',
#  'Elligator',
#  'PIRASO',
#  'ROYAL SON',
#  'ROZZETTA CRAFT',
#  'Sewell',
#  'PIRASO',
#  'Silver Kartz',
#  'ROYAL SON',
# ...

# %%
Product_Description=[]
start=0
end=4
for page in range(start,end):
    Product_tags=driver.find_elements(By.XPATH,'//div[@class="_2B099V"]')
    for i in Product_tags:
        Product_Description.append(i.text.split(' ')[1:4])
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')    
                                     
Product_Description[0:100]
# Out:
# [['Protection', 'Wayfarer', 'Sunglasses'],
#  ['Protection', 'Rectangular', 'Sunglasses'],
#  ['Specs\nUV', 'Protection', 'Rectangular'],
#  ['Kartz\nUV', 'Protection', 'Clubmaster'],
#  ['Protection,', 'Polarized', 'Wayfarer'],
#  ['CHASE\nUV', 'Protection', 'Wayfarer'],
#  ['Protection', 'Rectangular', 'Sunglasses'],
#  ['India\nGradient,', 'Toughened', 'Glass'],
#  ['Protection', 'Shield', 'Sunglasses'],
#  ['Protection', 'Aviator', 'Sunglasses'],
#  ['SON\nUV', 'Protection,', 'Polarized'],
#  ['CRAFT\nUV', 'Protection,', 'Gradient'],
#  ['CART\nMirrored,', 'Night', 'Vision'],
#  ['UV', 'Protection', 'Aviator'],
#  ['Protection', 'Round', 'Sunglasses'],
#  ['Protection', 'Wayfarer', 'Sunglasses'],
#  ['SON\nPolarized,', 'UV', 'Protection'],
#  ['CRAFT\nUV', 'Protection,', 'Gradient'],
#  ['Night', 'Vision,', 'UV'],
#  ['Protection', 'Aviator', 'Sunglasses'],
#  ['Kartz\nUV', 'Protection', 'Wayfarer'],
#  ['SON\nUV', 'Protection,', 'Polarized'],
# ...

# %%
Price=[]
start=0
end=4
for page in range(start,end):
    Price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in Price_tags:
        Price.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')    
                                     
Price[0:100]
# Out:
# ['₹649',
#  '₹199',
#  '₹254',
#  '₹279',
#  '₹283',
#  '₹649',
#  '₹519',
#  '₹607',
#  '₹649',
#  '₹251',
#  '₹699',
#  '₹426',
#  '₹219',
#  '₹296',
#  '₹318',
#  '₹251',
#  '₹664',
#  '₹379',
#  '₹265',
#  '₹251',
#  '₹288',
#  '₹664',
#  '₹474',
#  '₹236',
#  '₹220',
#  '₹579',
#  '₹426',
#  '₹759',
#  '₹176',
#  '₹949',
#  '₹474',
#  '₹664',
#  '₹939',
#  '₹323',
#  '₹579',
#  '₹439',
#  '₹699',
#  '₹699',
#  '₹519',
#  '₹189',
#  '₹649',
#  '₹199',
#  '₹254',
#  '₹279',
#  '₹283',
#  '₹649',
#  '₹519',
#  '₹607',
#  '₹649',
#  '₹251',
#  '₹699',
#  '₹426',
#  '₹219',
#  '₹296',
#  '₹318',
#  '₹251',
#  '₹664',
#  '₹379',
#  '₹265',
#  '₹251',
#  '₹288',
#  '₹664',
#  '₹474',
#  '₹236',
#  '₹220',
#  '₹579',
#  '₹426',
#  '₹759',
#  '₹176',
#  '₹949',
#  '₹474',
#  '₹664',
#  '₹939',
#  '₹323',
#  '₹579',
#  '₹439',
#  '₹699',
#  '₹699',
#  '₹519',
#  '₹189',
#  '₹649',
#  '₹199',
#  '₹254',
#  '₹279',
#  '₹283',
#  '₹649',
#  '₹519',
#  '₹607',
#  '₹649',
#  '₹251',
# ...

# %% [markdown]
# #Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link

# %%
url='https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR'
driver.get(url)

# %%
Rating=[]
start=0
end=10
for page in range(start,end):
    Rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in Rating_tags:
        Rating.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')    
                                     
Rating[0:100]
# Out:
# ['5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5']

# %%
Reviews_Summary=[]
start=0
end=10
for page in range(start,end):
    Reviews_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in Reviews_tags:
        Reviews_Summary.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')    
                                     
Reviews_Summary[0:100]
# Out:
# ['Simply awesome',
#  'Value-for-money',
#  'Perfect product!',
#  'Best in the market!',
#  'Highly recommended',
#  'Worth every penny',
#  'Highly recommended',
#  'Perfect product!',
#  'Pretty good',
#  'Great product',
#  'Simply awesome',
#  'Value-for-money',
#  'Perfect product!',
#  'Best in the market!',
#  'Highly recommended',
#  'Worth every penny',
#  'Highly recommended',
#  'Perfect product!',
#  'Pretty good',
#  'Great product',
#  'Simply awesome',
#  'Value-for-money',
#  'Perfect product!',
#  'Best in the market!',
#  'Highly recommended',
#  'Worth every penny',
#  'Highly recommended',
#  'Perfect product!',
#  'Pretty good',
#  'Great product',
#  'Simply awesome',
#  'Value-for-money',
#  'Perfect product!',
#  'Best in the market!',
#  'Highly recommended',
#  'Worth every penny',
#  'Highly recommended',
#  'Perfect product!',
#  'Pretty good',
#  'Great product',
#  'Simply awesome',
#  'Value-for-money',
#  'Perfect product!',
#  'Best in the market!',
# ...

# %%
Full_review=[]
start=0
end=10
for page in range(start,end):
    Full_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in Full_tags:
        Full_review.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')    
                                     
Full_review[0:100]
# Out:
# ['Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.',
#  "I'm Really happy with the product\nDelivery was fast as well\n..it was a gift for my sister and she loved it so much.",
#  'Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .',
#  'Great iPhone very snappy experience as apple kind. Upgraded from iPhone 7.\nPros\n-Camera top class\n- Battery top performed\n-Chipset no need to say as apple kind\n-Security as you expect from apple\n- Display super bright industry leading colour\naccuracy and super responsive\n-Build quality as expect from apple sturdy\npremium durable beautiful stylish.\n-Os most stable os in smartphone industry\n\nCons\n-No 5G\n-Display is not based on OLED technology\n-Charger headphones and 1 apple stic...\nREAD MORE',
# ...

# %% [markdown]
# #Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the
# search field.

# %%
url='https://www.flipkart.com/search?q=sneakers&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_Query_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=sneakers&requestId=e4b0024d-58f9-45c2-af81-c9fa8fa760f6'
driver.get(url)

# %%
search=driver.find_element(By.CLASS_NAME,'_3704LK')
search.send_keys("Sneakers”")

# %%
Brand=[]
start=0
end=10
for page in range(start,end):
    Brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in Brand_tags:
        Brand.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')    
                                     
Brand[0:100]
# Out:
# ['Numenzo',
#  'U.S. POLO ASSN.',
#  'RED TAPE',
#  'ASTEROID',
#  'RapidBox',
#  'RED TAPE',
#  'BRUTON',
#  'PUMA',
#  'Kraasa',
#  'SCATCHITE',
#  'U.S. POLO ASSN.',
#  'Kraasa',
#  'BRUTON',
#  'ASTEROID',
#  'aadi',
#  'BRUTON',
#  'Scull Wings',
#  'U.S. POLO ASSN.',
#  'Deals4you',
#  'World Wear Footwear',
#  'STEPWAY',
#  'U.S. POLO ASSN.',
#  'BRUTON',
#  'Sparx',
#  'World Wear Footwear',
#  'TR',
#  'U.S. POLO ASSN.',
#  'asian',
#  'BRUTON',
#  'BRUTON',
#  'PUMA',
#  'PUMA',
#  'BRUTON',
#  'BRUTON',
#  'World Wear Footwear',
#  'AMICO',
#  'PUMA',
#  'Zixer',
#  'City Soles',
#  'Shozie',
#  'Numenzo',
#  'U.S. POLO ASSN.',
#  'RED TAPE',
#  'ASTEROID',
#  'RapidBox',
#  'RED TAPE',
#  'BRUTON',
#  'PUMA',
#  'Kraasa',
#  'SCATCHITE',
#  'U.S. POLO ASSN.',
#  'Kraasa',
#  'BRUTON',
#  'ASTEROID',
#  'aadi',
#  'BRUTON',
#  'Scull Wings',
#  'U.S. POLO ASSN.',
#  'Deals4you',
#  'World Wear Footwear',
#  'STEPWAY',
#  'U.S. POLO ASSN.',
#  'BRUTON',
#  'Sparx',
# ...

# %%
Product_Description=[]
start=0
end=4
for page in range(start,end):
    Product_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in Product_tags:
        Product_Description.append(i.text.split(' ')[0:4])
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')    
                                     
Product_Description[0:100]
# Out:
# [['White', 'Sneaker', 'For', 'Men'],
#  ['MADRYN', '2.O', 'Sneakers', 'For'],
#  ['Sneakers', 'For', 'Men'],
#  ['Original', 'Luxury', 'Branded', 'Fashionable'],
#  ['Sneakers', 'For', 'Men'],
#  ['Sneakers', 'For', 'Men'],
#  ['Canvas', 'shoes', 'for', 'Men'],
#  ['Court', 'Star', 'Vulc', 'FS'],
#  ['Casuals,', 'Canvas,', 'Partywear', 'Sneakers'],
#  ['Sneakers', 'Sneakers', 'For', 'Men'],
#  ['OCTAVIA', 'Sneakers', 'For', 'Men'],
#  ['Sneakers', 'For', 'Men'],
#  ['Exclusive', 'Sneaker', 'Shoes', 'Sneakers'],
#  ['Original', 'Luxury', 'Branded', 'Fashionable'],
#  ['Sneakers', 'For', 'Men'],
#  ['Lattest', 'Sneakers', 'Shoe', 'Sneakers'],
#  ['GREEN', 'SNEAKERS', 'CASUAL', 'SHOES'],
#  ['Sneakers', 'For', 'Women'],
#  ['5011-Latest', 'Collection', 'Stylish', '&'],
#  ['LEBRON', '3.0', 'Sneakers', 'For'],
#  ['Lightweight', 'Pack', 'Of', '1'],
#  ['SM-671', 'Sneakers', 'For', 'Men'],
#  ['Exclusive', 'Affordable', 'Collection', 'of'],
#  ['GAIMAN', '2.O', 'Sneakers', 'For'],
# ...

# %%
Price=[]
start=0
end=4
for page in range(start,end):
    Price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in Price_tags:
        Price.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')    
                                     
Price[0:100]
# Out:
# ['₹550',
#  '₹2,379',
#  '₹999',
#  '₹499',
#  '₹630',
#  '₹1,079',
#  '₹389',
#  '₹2,879',
#  '₹499',
#  '₹360',
#  '₹1,199',
#  '₹499',
#  '₹350',
#  '₹499',
#  '₹249',
#  '₹311',
#  '₹539',
#  '₹1,859',
#  '₹359',
#  '₹249',
#  '₹499',
#  '₹1,934',
#  '₹199',
#  '₹879',
#  '₹296',
#  '₹299',
#  '₹1,499',
#  '₹899',
#  '₹324',
#  '₹311',
#  '₹2,399',
#  '₹1,709',
#  '₹179',
#  '₹317',
#  '₹249',
#  '₹494',
#  '₹1,749',
#  '₹565',
#  '₹659',
#  '₹629',
#  '₹550',
#  '₹2,379',
#  '₹999',
#  '₹499',
#  '₹630',
#  '₹1,079',
#  '₹389',
#  '₹2,879',
#  '₹499',
#  '₹360',
#  '₹1,199',
#  '₹499',
#  '₹350',
#  '₹499',
#  '₹249',
#  '₹311',
#  '₹539',
#  '₹1,859',
#  '₹359',
#  '₹249',
#  '₹499',
#  '₹1,934',
#  '₹199',
#  '₹879',
#  '₹296',
#  '₹299',
#  '₹1,499',
#  '₹899',
#  '₹324',
#  '₹311',
#  '₹2,399',
#  '₹1,709',
#  '₹179',
#  '₹317',
#  '₹249',
#  '₹494',
#  '₹1,749',
#  '₹565',
#  '₹659',
#  '₹629',
#  '₹550',
#  '₹2,379',
#  '₹999',
#  '₹499',
#  '₹630',
#  '₹1,079',
# ...

# %%
off=[]
start=0
end=10
for page in range(start,end):
    off_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in Price_tags:
        off.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')    
                                     
off[0:100]
# Out:
# ['₹550',
#  '₹2,379',
#  '₹999',
#  '₹499',
#  '₹630',
#  '₹1,079',
#  '₹389',
#  '₹2,879',
#  '₹499',
#  '₹360',
#  '₹1,199',
#  '₹499',
#  '₹350',
#  '₹499',
#  '₹249',
#  '₹311',
#  '₹539',
#  '₹1,859',
#  '₹359',
#  '₹249',
#  '₹499',
#  '₹1,934',
#  '₹199',
#  '₹879',
#  '₹296',
#  '₹299',
#  '₹1,499',
#  '₹899',
#  '₹324',
#  '₹311',
#  '₹2,399',
#  '₹1,709',
#  '₹179',
#  '₹317',
#  '₹249',
#  '₹494',
#  '₹1,749',
#  '₹565',
#  '₹659',
#  '₹629',
#  '₹550',
#  '₹2,379',
#  '₹999',
#  '₹499',
#  '₹630',
#  '₹1,079',
#  '₹389',
#  '₹2,879',
#  '₹499',
#  '₹360',
#  '₹1,199',
#  '₹499',
#  '₹350',
#  '₹499',
#  '₹249',
#  '₹311',
#  '₹539',
#  '₹1,859',
#  '₹359',
#  '₹249',
#  '₹499',
#  '₹1,934',
#  '₹199',
#  '₹879',
#  '₹296',
#  '₹299',
#  '₹1,499',
#  '₹899',
#  '₹324',
#  '₹311',
#  '₹2,399',
#  '₹1,709',
#  '₹179',
#  '₹317',
#  '₹249',
#  '₹494',
#  '₹1,749',
#  '₹565',
#  '₹659',
#  '₹629',
#  '₹550',
#  '₹2,379',
#  '₹999',
#  '₹499',
#  '₹630',
#  '₹1,079',
# ...

# %% [markdown]
# #Q7: Go to the link - https://www.myntra.com/shoe

# %%
url='https://www.myntra.com/shoes'
driver.get(url)

# %%
Brand=[]
start=0
end=10
for page in range(start,end):
    Brand_tags=driver.find_elements(By.XPATH,'//h3[@class="product-brand"]')
    for i in Brand_tags:
        Brand.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')    
                                     
Brand[0:100]
# Out:
# ['ADIDAS',
#  'Nike',
#  'ADIDAS Originals',
#  'Nike',
#  'PUMA Motorsport',
#  'ADIDAS',
#  'Puma',
#  'UNDER ARMOUR',
#  'UNDER ARMOUR',
#  'UNDER ARMOUR',
#  'Puma',
#  'Nike',
#  'Skechers',
#  'Nike',
#  'ADIDAS',
#  'Skechers',
#  'Puma',
#  'Saint G',
#  'UNDER ARMOUR',
#  'Nike',
#  'UNDER ARMOUR',
#  'Nike',
#  'Puma',
#  'Nike',
#  'Calvin Klein',
#  'Ruosh',
#  'Puma',
#  'ADIDAS',
#  'ALDO',
#  'ADIDAS Originals',
#  'Puma',
#  'ADIDAS',
#  'Skechers',
#  'Saint G',
#  'Xtep',
#  'Nike',
#  'Nike',
#  'ADIDAS Originals',
#  'Puma',
#  'Saint G',
#  'Xtep',
#  'ADIDAS Originals',
#  'MANGO',
#  'Skechers',
#  'Calvin Klein',
#  'ADIDAS Originals',
#  'UNDER ARMOUR',
#  'Nike',
#  'Saint G',
#  'Columbia',
#  'ADIDAS',
#  'Nike',
#  'ADIDAS Originals',
#  'Nike',
#  'PUMA Motorsport',
#  'ADIDAS',
#  'Puma',
#  'UNDER ARMOUR',
#  'UNDER ARMOUR',
#  'UNDER ARMOUR',
#  'Puma',
#  'Nike',
#  'Skechers',
#  'Nike',
#  'ADIDAS',
#  'Skechers',
#  'Puma',
#  'Saint G',
# ...

# %%
Price=[]
start=0
end=4
for page in range(start,end):
    Price_tags=driver.find_elements(By.XPATH,'//span[@class="product-discountedPrice"]')
    for i in Price_tags:
        Price.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')    
                                     
Price[0:100]
# Out:
# ['Rs. 13599',
#  'Rs. 9715',
#  'Rs. 10399',
#  'Rs. 12145',
#  'Rs. 7199',
#  'Rs. 12749',
#  'Rs. 11049',
#  'Rs. 9099',
#  'Rs. 7465',
#  'Rs. 7649',
#  'Rs. 7649',
#  'Rs. 13410',
#  'Rs. 7645',
#  'Rs. 8249',
#  'Rs. 7645',
#  'Rs. 7679',
#  'Rs. 8399',
#  'Rs. 10399',
#  'Rs. 9099',
#  'Rs. 10399',
#  'Rs. 7499',
#  'Rs. 9810',
#  'Rs. 7199',
#  'Rs. 12745',
#  'Rs. 12799',
#  'Rs. 9349',
#  'Rs. 8010',
#  'Rs. 7199',
#  'Rs. 7699',
#  'Rs. 7649',
#  'Rs. 8399',
#  'Rs. 11996',
#  'Rs. 7560',
#  'Rs. 13599',
#  'Rs. 9715',
#  'Rs. 10399',
#  'Rs. 12145',
#  'Rs. 7199',
#  'Rs. 12749',
#  'Rs. 11049',
#  'Rs. 9099',
#  'Rs. 7465',
#  'Rs. 7649',
#  'Rs. 7649',
#  'Rs. 13410',
#  'Rs. 7645',
#  'Rs. 8249',
#  'Rs. 7645',
#  'Rs. 7679',
#  'Rs. 8399',
#  'Rs. 10399',
#  'Rs. 9099',
#  'Rs. 10399',
#  'Rs. 7499',
#  'Rs. 9810',
#  'Rs. 7199',
#  'Rs. 12745',
#  'Rs. 12799',
#  'Rs. 9349',
#  'Rs. 8010',
#  'Rs. 7199',
#  'Rs. 7699',
#  'Rs. 7649',
#  'Rs. 8399',
#  'Rs. 11996',
# ...

# %%
Product_Description=[]
start=0
end=4
for page in range(start,end):
    Product_tags=driver.find_elements(By.XPATH,'//h4[@class="product-product"]')
    for i in Product_tags:
        Product_Description.append(i.text.split(' ')[1:4])
    next_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')    
                                     
Product_Description[0:100]
# Out:
# [['Ultraboost', '5.0', 'DNA'],
#  ['AIR', 'MAX', 'DAWN'],
#  ['Woven', 'Nmd_R1', 'Sneakers'],
#  ['Vomero', '16', 'Running'],
#  ['MAPF1', 'Drift', 'Sneakers'],
#  ['Runner', 'Fl', 'Running'],
#  ['Nitro', 'Running', 'Shoes'],
#  ['HOVR', 'SonicSE', 'Running'],
#  ['3ZER0', 'IV', 'Basketball'],
#  ['ChargedEscape', '3', 'BL'],
#  ['M', 'Nitro', 'Running'],
#  ['RN', '5.0', 'NEXT'],
#  ['Sky', 'Vault', 'Walking'],
#  ['JORDAN', 'LOW', 'Basketball'],
#  ['Response', 'Super', '3.0'],
#  ['Walking', 'Shoes'],
#  ['FUSE', 'Performance', 'Training'],
#  ['Above', 'The', 'Knee'],
#  ['HOVR', 'SonicSE', 'Running'],
#  ['Kyrie', 'Flytrap', 'Basketball'],
#  ['HOVR', 'SonicSE', 'Running'],
#  ['FREE', 'RUN', '2'],
#  ['Liberate', 'Running', 'Shoes'],
#  ['AIR', 'WINFLO', '9'],
#  ['Printed', 'Leather', 'Sneakers'],
#  ['Textured', 'Leather', 'Loafers'],
#  ['Nitro', '2', 'WIDE'],
#  ['Response', 'Super', '3.0'],
#  ['Regular', 'Boots'],
#  ['Checked', 'NMD_R1', 'Sneakers'],
# ...

# %% [markdown]
# #Q8: Go to webpage https://www.amazon.in

# %%
url='https://www.amazon.in/'
driver.get(url)

# %%
Titles=[]
start=0
end=10
for page in range(start,end):
    Titles_tags=driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
    for i in Titles_tags:
        Titles.append(i.text)
    next_button=driver.find_elements(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')    
                                     
Titles[0:10]
# Out:
# ['Samsung Galaxy Book2 Pro Intel 12th Gen i7 EvoTM 39.62cm (15.6") AMOLED Thin & Light Laptop (16 GB/512 GB SSD/Windows 11/MS Office/Backlit KB/Fingerprint Sensor/Graphite/1.11Kg), NP950XED-KA1IN',
#  'Samsung Galaxy Book2 360 Intel 12th Gen i7 EvoTM 33.78cm (13.3") AMOLED 2 in 1 Touch Screen Laptop (16 GB/512 GB SSD/Windows 11/MS Office/Backlit KB/Fingerprint Sensor/Graphite/1.16Kg), NP730QED-KA1IN',
#  'Lenovo ThinkBook 15 Intel 11th Gen Core i7 15.6"(39.62 cm) FHD Thin and Light Laptop (16GB/512GB SSD/Windows 11 Home/MS Office H&S 2021/Iris® Xe Graphics/Backlit/Mineral Grey/1.7 Kg) 20VE00W4IH',
#  '(Renewed) HP ProBook 430 G3 6th Gen Intel Core i7 Thin & Light HD Laptop (8 GB DDR4 RAM/256 GB SSD/13.3" (33.8 cm)/Windows 11/MS Office/Wifi/Bluetooth 4.0/Webcam/Integrated Graphics)',
# ...

# %%
price=[]
price_tags=driver.find_elements(By.XPATH,'//span[@class="a-price"]')
for i in price_tags:
    price.append(i.text)
price[0:10]
# Out:
# ['₹1,11,000',
#  '₹97,990',
#  '₹80,900',
#  '₹25,895',
#  '₹83,990',
#  '₹80,990',
#  '₹93,999',
#  '₹82,990',
#  '₹84,407',
#  '₹81,490']

# %% [markdown]
# #Q9: Write a python program to scrape data for Top 1000 Quotes of All Tim

# %%
url='https://www.azquotes.com/'
driver.get(url)

# %%
search_btn=driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a')
search_btn.click()

# %%
Quote=[]
Quote_tags=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in Quote_tags:
    Quote.append(i.text)
Quote
# Out:
# ['Essence, Deep Thought, Transcendentalism',
#  'Inspiration, Past, Trying',
#  'Country, Peace, War',
#  'Inspirational, Motivational, Death',
#  '4th Of July, Food, Patriotic',
#  'Inspirational, Success, Basketball',
#  'Strong, Revenge, Intelligent',
#  'Inspirational, Teacher, Religious',
#  'Truth, Honesty, Lying',
#  'Funny, Reading, Learning',
#  'Strong, Thoughtful, Compassion',
#  'Love, Funny, Life',
#  'Freedom, Men, Democracies Have',
#  'God, Religious, Atheist',
#  'Respect, Kindness, Character',
#  'Inspirational, Motivational, Change',
#  'Inspirational, Life, Inspiring',
#  'Love, Inspirational, Life',
#  'Inspiring, Country, 4th Of July',
#  'Inspirational, Dream, Hate',
#  'Love, Inspirational, Life',
#  'Forgiveness, God, Christian',
#  'Country, Men, Squares',
#  'Inspirational, Relationship, Positive',
#  'Inspirational, Motivational, Positive',
#  'Love, Friendship, Relationship',
#  'Faith, God, Christian',
#  'Art, Freedom, Political Will',
# ...

# %%
Author=[]
Author_tags=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in Author_tags:
    Author.append(i.text)
Author
# Out:
# ['Michael Porter',
#  'Golda Meir',
#  'Theodore Roosevelt',
#  'Nelson Mandela',
#  'Erma Bombeck',
#  'John Wooden',
#  'Albert Einstein',
#  'Frank Zappa',
#  'William Faulkner',
#  'Will Rogers',
#  'Jimmy Carter',
#  'Albert Einstein',
#  'Abraham Lincoln',
#  'Steven Weinberg',
#  'Franklin D. Roosevelt',
#  'Albert Einstein',
#  'Maya Angelou',
#  'Mark Twain',
#  'Theodore Roosevelt',
#  'Michael Jackson',
#  'Martin Luther King, Jr.',
#  'C. S. Lewis',
#  'Theodore Roosevelt',
#  'Mark Twain',
#  'Abraham Lincoln',
#  'Ruth Graham',
#  'C. S. Lewis',
#  'Groucho Marx',
#  'John Lennon',
#  'Barbara Bush',
#  'Albert Einstein',
#  'Francis Chan',
#  'Henry Ford',
#  'Victor Hugo',
#  'Abu Bakr',
#  'Zig Ziglar',
#  'Winston Churchill',
#  'Zig Ziglar',
#  'John F. Kennedy',
#  'Dwight D. Eisenhower',
#  'Winston Churchill',
#  'Albert Einstein',
#  'Willie Nelson',
#  'Johnny Cash',
#  'Marie Curie',
#  'Maya Angelou',
#  'Amy Bloom',
#  'Zig Ziglar',
#  'John Lennon',
# ...

# %%
type_quote=[]
quote_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in quote_tags:
    type_quote.append(i.text)
type_quote
# Out:
# ['The essence of strategy is choosing what not to do.',
#  'One cannot and must not try to erase the past merely because it does not fit the present.',
#  'Patriotism means to stand by the country. It does not mean to stand by the president.',
#  'Death is something inevitable. When a man has done what he considers to be his duty to his people and his country, he can rest in peace. I believe I have made that effort and that is, therefore, why I will sleep for the eternity.',
#  'You have to love a nation that celebrates its independence every July 4, not with a parade of guns, tanks, and soldiers who file by the White House in a show of strength and muscle, but with family picnics where kids throw Frisbees, the potato salad gets iffy, and the flies die from happiness. You may think you have overeaten, but it is patriotism.',
# ...

# %% [markdown]
# #Q10: Write s python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead,
# Term of office, Remarks) from https://www.jagranjosh.com/.

# %%
url='https://www.jagranjosh.com/'
driver.get(url)

# %%
search_btn=driver.find_element(By.XPATH, '/html/body/div/div[1]/div/div[1]/div/div[6]/div/div[1]/header/div[3]/ul/li[9]/a')
search_btn.click()

# %%
search_btn=driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
search_btn.click()

# %%
minister=[]
minister_tags=driver.find_elements(By.XPATH,'//div[@class="table-box"]')
for i in minister_tags:
    minister.append(i.text)
minister
# Out:
# ["S.N.\nName\nBorn-Dead\nTerm of office\nRemark\n1.\nJawahar Lal Nehru\n(1889–1964)\n15 August 1947 to 27 May 1964\n16 years, 286 days\nThe first prime minister of India and the longest-serving PM of India, the first to die in office.\n2.\nGulzarilal Nanda (Acting)\n(1898-1998)\n27 May 1964 to 9 June 1964,\n13 days\nFirst acting PM of India\n3.\nLal Bahadur Shastri\n(1904–1966)\n9 June 1964 to 11 January 1966\n1 year, 216 days\nHe has given the slogan of 'Jai Jawan Jai Kisan' during the Indo-Pak war of 1965\n4. \nGulzari Lal Nanda  (Acting)\n(1898-1998)\n11 January 1966 to 24 January 1966\n13 days\n-\n5.\nIndira Gandhi\n(1917–1984)\n24 January 1966 to 24 March 1977\n11 years, 59 days\nFirst female Prime Minister of India\n6.\nMorarji Desai\n(1896–1995)\n24 March 1977 to  28 July 1979 \n2 year, 126 days\nOldest to become PM (81 years old) and first to resign from office\n7.\nCharan Singh\n(1902–1987)\n28 July 1979 to 14 January 1980\n170 days\nOnly PM who did not face the Parliament\n
# ...

# %% [markdown]
# #Q11: Write s python program to display list of 50 Most expensive cars in the world (i.e. Company name, Model
# name and Price) from https://www.motor1.com

# %%
url='https://www.motor1.com/'
driver.get(url)

# %%
search_btn=driver.find_element(By.XPATH, '/html/body/div[3]/div[1]/div[3]/ul/li[4]/a')
search_btn.click()

# %%
search_btn=driver.find_element(By.XPATH, '/html/body/div[2]/div[9]/div[1]/div[1]/div/div/div[1]/div/div[1]/h3/a')
search_btn.click()

# %%
Name=[]
Name_tags=driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in Name_tags:
    Name.append(i.text)
Name
# Out:
# ['Drako GTE',
#  'De Tomaso P72',
#  'Ferrari LaFerrari',
#  'Pagani Huayra',
#  'McLaren Elva',
#  'Czinger 21C',
#  'Ferrari Monza',
#  'Gordon Murray T.33',
#  'Koenigsegg Gemera',
#  'Zenvo TSR-S',
#  'Hennessey Venom F5',
#  'Bentley Bacalar',
#  'Hispano Suiza Carmen Boulogne',
#  'Bentley Mulliner Batur',
#  'Deus Vayanne',
#  'SSC Tuatara',
#  'Lotus Evija',
#  'Aston Martin Vulcan',
#  'Delage D12',
#  'McLaren Speedtail',
#  'Rimac Nevera',
#  'Pagani Utopia',
#  'Pininfarina Battista',
#  'Ferrari FXX K Evo',
#  'Gordon Murray T.50',
#  'Lamborghini Countach',
#  'Mercedes-AMG Project One',
#  'Aston Martin Victor',
#  'Hennessey Venom F5 Roadster',
#  'Koenigsegg Jesko',
#  'Aston Martin Valkyrie',
#  'W Motors Lykan Hypersport',
#  'McLaren Solus',
#  'Pagani Huayra Roadster BC',
#  'Bugatti Chiron Pur Sport',
#  'Lamborghini Sian',
#  'Koenigsegg CC850',
#  'Bugatti Chiron Super Sport 300+',
#  'Lamborghini Veneno',
#  'Bugatti Bolide',
#  'Bugatti Mistral',
# ...
